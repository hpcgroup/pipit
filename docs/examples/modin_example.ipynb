# %%
# %load_ext autoreload
# %autoreload 1

# %%
import sys
sys.path.append('../../')

# %%
import pipit as pp
pp
# Out:
# <module 'pipit' from '/home/rakrish/pipit/docs/examples/../../pipit/__init__.py'>

# %%
import modin.pandas as pd
df = pd.read_parquet('/home/rakrish/trace-analysis/amg_16.parquet')
df
# Out:
# ...
# To remove this warning, run the following python code before doing dataframe operations:
#
#     import ray
#     ray.init(runtime_env={'env_vars': {'__MODIN_AUTOIMPORT_PANDAS__': '1'}})
#
# 2023-10-04 08:32:51,596	INFO worker.py:1553 -- Started a local Ray instance.
# (raylet) Error processing line 1 of /home/rakrish/.local/lib/python3.8/site-packages/modin-autoimport-pandas.pth:
# (raylet)
# (raylet)   Traceback (most recent call last):
# (raylet)     File "/usr/lib/python3.8/site.py", line 175, in addpackage
# (raylet)       exec(line)
# (raylet)     File "<string>", line 1, in <module>
# (raylet)     File "/home/rakrish/.local/lib/python3.8/site-packages/pandas/__init__.py", line 22, in <module>
# (raylet)       from pandas.compat import is_numpy_dev as _is_numpy_dev  # pyright: ignore # noqa:F401
# (raylet)     File "/home/rakrish/.local/lib/python3.8/site-packages/pandas/compat/__init__.py", line 18, in <module>
# (raylet)       from pandas.compat.numpy import (
# ...

# %%
trace = pp.Trace(events=df, definitions=None)

# %%
type(trace.events)
# Out:
# modin.pandas.dataframe.DataFrame

# %%
trace.events
# Out:
#          Timestamp (ns) Event Type                 Name  Thread  Process  \
# 0          0.000000e+00    Instant         ProgramBegin       0       12
# 1          4.677470e+01    Instant         ProgramBegin       0       13
# 2          7.159393e+01    Instant         ProgramBegin       0       15
# 3          1.002315e+02    Instant         ProgramBegin       0       14
# 4          2.484978e+04      Enter             MPI_Init       0       15
# ...                 ...        ...                  ...     ...      ...
# 5010746    3.315713e+09    Instant     MeasurementOnOff       0        5
# 5010747    3.315713e+09    Instant     MeasurementOnOff       0        6
# 5010748    3.315713e+09    Instant     MeasurementOnOff       0        7
# 5010749    3.315718e+09      Leave  TRACER_WallTime_amg       0        0
# 5010750    3.315728e+09    Instant     MeasurementOnOff       0        0
#
#                                                 Attributes
# ...

# %%
trace.comm_matrix()
# Out:
# ...
# Please refer to https://modin.readthedocs.io/en/stable/supported_apis/defaulting_to_pandas.html for explanation.
# (raylet) Error processing line 1 of /home/rakrish/.local/lib/python3.8/site-packages/modin-autoimport-pandas.pth:
# (raylet)
# (raylet)   Traceback (most recent call last):
# (raylet)     File "/usr/lib/python3.8/site.py", line 175, in addpackage
# (raylet)       exec(line)
# (raylet)     File "<string>", line 1, in <module>
# (raylet)     File "/home/rakrish/.local/lib/python3.8/site-packages/pandas/__init__.py", line 22, in <module>
# (raylet)       from pandas.compat import is_numpy_dev as _is_numpy_dev  # pyright: ignore # noqa:F401
# (raylet)     File "/home/rakrish/.local/lib/python3.8/site-packages/pandas/compat/__init__.py", line 18, in <module>
# (raylet)       from pandas.compat.numpy import (
# (raylet)     File "/home/rakrish/.local/lib/python3.8/site-packages/pandas/compat/numpy/__init__.py", line 4, in <module>
# ...

# %%
trace._match_events()

# %%
trace.events
# Out:
#          Timestamp (ns) Event Type                 Name  Thread  Process  \
# 0          0.000000e+00    Instant         ProgramBegin       0       12
# 1          4.677470e+01    Instant         ProgramBegin       0       13
# 2          7.159393e+01    Instant         ProgramBegin       0       15
# 3          1.002315e+02    Instant         ProgramBegin       0       14
# 4          2.484978e+04      Enter             MPI_Init       0       15
# ...                 ...        ...                  ...     ...      ...
# 5010746    3.315713e+09    Instant     MeasurementOnOff       0        5
# 5010747    3.315713e+09    Instant     MeasurementOnOff       0        6
# 5010748    3.315713e+09    Instant     MeasurementOnOff       0        7
# 5010749    3.315718e+09      Leave  TRACER_WallTime_amg       0        0
# 5010750    3.315728e+09    Instant     MeasurementOnOff       0        0
#
#                                                 Attributes  _matching_event  \
# ...

# %%
trace._match_caller_callee()

# %%
trace.events
# Out:
#          Timestamp (ns) Event Type                 Name  Thread  Process  \
# 0          0.000000e+00    Instant         ProgramBegin       0       12
# 1          4.677470e+01    Instant         ProgramBegin       0       13
# 2          7.159393e+01    Instant         ProgramBegin       0       15
# 3          1.002315e+02    Instant         ProgramBegin       0       14
# 4          2.484978e+04      Enter             MPI_Init       0       15
# ...                 ...        ...                  ...     ...      ...
# 5010746    3.315713e+09    Instant     MeasurementOnOff       0        5
# 5010747    3.315713e+09    Instant     MeasurementOnOff       0        6
# 5010748    3.315713e+09    Instant     MeasurementOnOff       0        7
# 5010749    3.315718e+09      Leave  TRACER_WallTime_amg       0        0
# 5010750    3.315728e+09    Instant     MeasurementOnOff       0        0
#
#                                                 Attributes  _matching_event  \
# ...

# %%
trace.calc_inc_metrics()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In [22], line 1
# ----> 1 trace.calc_inc_metrics()
#
# File ~/pipit/docs/examples/../../pipit/trace.py:308, in Trace.calc_inc_metrics(self, columns)
#     297 metric_col_name = ("time" if col == "Timestamp (ns)" else col) + ".inc"
#     299 if metric_col_name not in self.events.columns:
#     300     # calculate the inclusive metric by subtracting
#     301     # the values at the enter rows from the values
#     302     # at the corresponding leave rows
#     303     self.events.loc[
#     304         (self.events["_matching_event"].notnull())
#     305         & (self.events["Event Type"] == "Enter"),
#     306         metric_col_name,
#     307     ] = (
# --> 308         self.events[col][enter_df["_matching_event"]].values
#     309         - enter_df[col].values
#     310     )
# ...

# %%
trace.calc_exc_metrics()
# Out:
# ...
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 trace.calc_exc_metrics()
#
# File ~/pipit/docs/examples/../../pipit/trace.py:332, in Trace.calc_exc_metrics(self, columns)
#     330 inc_col_name = ("time" if col == "Timestamp (ns)" else col) + ".inc"
#     331 if inc_col_name not in self.events.columns:
# --> 332     self.calc_inc_metrics([col])
#     334 # name of column for this exclusive metric
#     335 metric_col_name = ("time" if col == "Timestamp (ns)" else col) + ".exc"
#
# File ~/pipit/docs/examples/../../pipit/trace.py:308, in Trace.calc_inc_metrics(self, columns)
#     297 metric_col_name = ("time" if col == "Timestamp (ns)" else col) + ".inc"
#     299 if metric_col_name not in self.events.columns:
#     300     # calculate the inclusive metric by subtracting
#     301     # the values at the enter rows from the values
# ...

# %%
trace.calc_inc_metrics(["Timestamp (ns)"])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 trace.calc_inc_metrics(["Timestamp (ns)"])
#
# File ~/pipit/docs/examples/../../pipit/trace.py:308, in Trace.calc_inc_metrics(self, columns)
#     297 metric_col_name = ("time" if col == "Timestamp (ns)" else col) + ".inc"
#     299 if metric_col_name not in self.events.columns:
#     300     # calculate the inclusive metric by subtracting
#     301     # the values at the enter rows from the values
#     302     # at the corresponding leave rows
#     303     self.events.loc[
#     304         (self.events["_matching_event"].notnull())
#     305         & (self.events["Event Type"] == "Enter"),
#     306         metric_col_name,
#     307     ] = (
# --> 308         self.events[col][enter_df["_matching_event"]].values
#     309         - enter_df[col].values
#     310     )
# ...

# %%
trace.numeric_cols
# Out:
# ['Timestamp (ns)', 'Thread', 'Process']

# %%
trace.message_histogram()
# Out:
# ---------------------------------------------------------------------------
# RayTaskError(TypeError)                   Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 trace.message_histogram()
#
# File ~/pipit/docs/examples/../../pipit/trace.py:439, in Trace.message_histogram(self, bins, **kwargs)
#     436 messages = self.events[self.events["Name"].isin(["MpiSend", "MpiIsend"])]
#     438 # Get message sizes
# --> 439 sizes = messages["Attributes"].map(lambda x: x["msg_length"])
#     441 return np.histogram(sizes, bins=bins, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/modin/logging/logger_decorator.py:128, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     113 """
#     114 Compute function with logging if Modin logging is enabled.
#     115
#    (...)
#     125 Any
#     126 """
#     127 if LogMode.get() == "disable":
# --> 128     return obj(*args, **kwargs)
#     130 logger = get_logger()
# ...

# %%
trace.flat_profile()
# Out:
# ...
# Empty DataFrame
# Columns: []
# Index: [MPI_Allgather, MPI_Allgatherv, MPI_Allreduce, MPI_Barrier, MPI_Bcast, MPI_Init, MPI_Iprobe, MPI_Irecv, MPI_Isend, MPI_Recv, MPI_Recv_init, MPI_Scan, MPI_Send, MPI_Send_init, MPI_Startall, MPI_Wait, MPI_Waitall, TRACER_Loop, TRACER_WallTime_amg]
# (raylet) Error processing line 1 of /home/rakrish/.local/lib/python3.8/site-packages/modin-autoimport-pandas.pth:
# (raylet)
# (raylet)   Traceback (most recent call last):
# (raylet)     File "/usr/lib/python3.8/site.py", line 175, in addpackage
# (raylet)       exec(line)
# (raylet)     File "<string>", line 1, in <module>
# (raylet)     File "/home/rakrish/.local/lib/python3.8/site-packages/pandas/__init__.py", line 22, in <module>
# (raylet)       from pandas.compat import is_numpy_dev as _is_numpy_dev  # pyright: ignore # noqa:F401
# (raylet)     File "/home/rakrish/.local/lib/python3.8/site-packages/pandas/compat/__init__.py", line 18, in <module>
# ...

# %%
trace.load_imbalance()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [18], line 1
# ----> 1 trace.load_imbalance()
#
# File ~/pipit/docs/examples/../../pipit/trace.py:491, in Trace.load_imbalance(self, metric, num_processes)
#     488 num_ranks = len(set(self.events["Process"]))
#     489 num_display = num_ranks if num_processes > num_ranks else num_processes
# --> 491 flat_profile = self.flat_profile(metrics=metric, per_process=True)
#     493 imbalance_dict = dict()
#     495 imb_metric = metric + ".imbalance"
#
# File ~/pipit/docs/examples/../../pipit/trace.py:461, in Trace.flat_profile(self, metrics, groupby_column, per_process)
#     456 # This first groups by both the process and the specified groupby
#     457 # column (like name). It then sums up the metrics for each combination
#     458 # of the process and the groupby column.
#     459 if per_process:
#     460     return (
# ...

# %%
trace.idle_time()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In [21], line 1
# ----> 1 trace.idle_time()
#
# File ~/pipit/docs/examples/../../pipit/trace.py:526, in Trace.idle_time(self, idle_functions, MPI_events)
#     523 for process in set(self.events["Process"]):
#     524     idle_times["Process"].append(process)
#     525     idle_times["Idle Time"].append(
# --> 526         self._calculate_idle_time_for_process(
#     527             process, idle_functions, MPI_events
#     528         )
#     529     )
#     530 return pd.DataFrame(idle_times)
#
# File ~/pipit/docs/examples/../../pipit/trace.py:537, in Trace._calculate_idle_time_for_process(self, process, idle_functions, MPI_events)
#     532 def _calculate_idle_time_for_process(
#     533     self, process, idle_functions=["Idle"], MPI_events=False
#     534 ):
#     535     # calculate inclusive metrics
# ...
