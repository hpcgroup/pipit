# %%
# Set up notebook for development
# %load_ext autoreload
# %autoreload 2

# Set up paths
import sys

sys.path.append("../../.")
del sys.path[0]

import pipit as pp
import pandas as pd

# %%
df = pd.read_pickle("C:/Users/Rakrish/Downloads/pingPong.pkl", compression="zip")
trace = pp.Trace(None, df)

# %%
# Simple filter
trace.where("Timestamp (ns)", "<", 1.35e08)
# Out:
# Timestamp (ns) < 135000000.0

# %%
# Execute simple filter
trace.where("Timestamp (ns)", "<", 1.35e08).get()
# Out:
#            Event  Timestamp (ns)      Name Location ID Location Type  \
# 0   ProgramBegin    0.000000e+00       N/A           1    CPU_THREAD
# 1   ProgramBegin    1.295053e+05       N/A           0    CPU_THREAD
# 2          Enter    1.618990e+05  MPI_Init           0    CPU_THREAD
# 3          Enter    2.519928e+05  MPI_Init           1    CPU_THREAD
# 4          Leave    1.305041e+08  MPI_Init           1    CPU_THREAD
# ..           ...             ...       ...         ...           ...
# 94         Leave    1.347616e+08  MPI_Recv           1    CPU_THREAD
# 95         Enter    1.347620e+08  MPI_Send           1    CPU_THREAD
# 96       MpiSend    1.347623e+08       N/A           1    CPU_THREAD
# 97         Leave    1.347649e+08  MPI_Send           0    CPU_THREAD
# 98         Enter    1.347653e+08  MPI_Recv           0    CPU_THREAD
#
#    Location Group ID Location Group Type  \
# 0                  1             PROCESS
# 1                  0             PROCESS
# 2                  0             PROCESS
# 3                  1             PROCESS
# 4                  1             PROCESS
# ..               ...                 ...
# 94                 1             PROCESS
# 95                 1             PROCESS
# 96                 1             PROCESS
# 97                 0             PROCESS
# 98                 0             PROCESS
#
#                                            Attributes
# 0   {'attributes': {'Attribute 2': 15968}, 'progra...
# 1   {'attributes': {'Attribute 2': 15964}, 'progra...
# 2                             {'region': 'Region 36'}
# 3                             {'region': 'Region 36'}
# 4                                                None
# ..                                                ...
# 94                                               None
# 95                            {'region': 'Region 67'}
# 96  {'receiver': 0, 'communicator': 'Comm 1', 'msg...
# 97                                               None
# 98                            {'region': 'Region 55'}
#
# [99 rows x 8 columns]

# %%
# Logical AND
trace.where("Timestamp (ns)", "<=", 1.35e08).where("Timestamp (ns)", ">=", 2.5e05).get()
# Out:
#       Event  Timestamp (ns)      Name Location ID Location Type  \
# 3     Enter    2.519928e+05  MPI_Init           1    CPU_THREAD
# 4     Leave    1.305041e+08  MPI_Init           1    CPU_THREAD
# 5     Leave    1.305043e+08  MPI_Init           0    CPU_THREAD
# 6     Enter    1.305330e+08  MPI_Recv           1    CPU_THREAD
# 7     Enter    1.305356e+08  MPI_Send           0    CPU_THREAD
# ..      ...             ...       ...         ...           ...
# 94    Leave    1.347616e+08  MPI_Recv           1    CPU_THREAD
# 95    Enter    1.347620e+08  MPI_Send           1    CPU_THREAD
# 96  MpiSend    1.347623e+08       N/A           1    CPU_THREAD
# 97    Leave    1.347649e+08  MPI_Send           0    CPU_THREAD
# 98    Enter    1.347653e+08  MPI_Recv           0    CPU_THREAD
#
#    Location Group ID Location Group Type  \
# 3                  1             PROCESS
# 4                  1             PROCESS
# 5                  0             PROCESS
# 6                  1             PROCESS
# 7                  0             PROCESS
# ..               ...                 ...
# 94                 1             PROCESS
# 95                 1             PROCESS
# 96                 1             PROCESS
# 97                 0             PROCESS
# 98                 0             PROCESS
#
#                                            Attributes
# 3                             {'region': 'Region 36'}
# 4                                                None
# 5                                                None
# 6                             {'region': 'Region 55'}
# 7                             {'region': 'Region 67'}
# ..                                                ...
# 94                                               None
# 95                            {'region': 'Region 67'}
# 96  {'receiver': 0, 'communicator': 'Comm 1', 'msg...
# 97                                               None
# 98                            {'region': 'Region 55'}
#
# [96 rows x 8 columns]

# %%
# Logical OR
trace.where("Name", "in", ["MPI_Recv", "MpiSend", "ProgramEnd"]).get()
# Out:
#      Event  Timestamp (ns)      Name Location ID Location Type  \
# 6    Enter    1.305330e+08  MPI_Recv           1    CPU_THREAD
# 10   Enter    1.305554e+08  MPI_Recv           0    CPU_THREAD
# 12   Leave    1.305630e+08  MPI_Recv           1    CPU_THREAD
# 17   Leave    1.305851e+08  MPI_Recv           0    CPU_THREAD
# 18   Enter    1.305905e+08  MPI_Recv           1    CPU_THREAD
# 22   Enter    1.306355e+08  MPI_Recv           0    CPU_THREAD
# 24   Leave    1.306362e+08  MPI_Recv           1    CPU_THREAD
# 29   Leave    1.306556e+08  MPI_Recv           0    CPU_THREAD
# 30   Enter    1.306743e+08  MPI_Recv           1    CPU_THREAD
# 34   Leave    1.307027e+08  MPI_Recv           1    CPU_THREAD
# 38   Enter    1.307060e+08  MPI_Recv           0    CPU_THREAD
# 41   Leave    1.307403e+08  MPI_Recv           0    CPU_THREAD
# 44   Enter    1.308216e+08  MPI_Recv           1    CPU_THREAD
# 46   Leave    1.308557e+08  MPI_Recv           1    CPU_THREAD
# 50   Enter    1.308583e+08  MPI_Recv           0    CPU_THREAD
# 53   Leave    1.309106e+08  MPI_Recv           0    CPU_THREAD
# 56   Enter    1.310765e+08  MPI_Recv           1    CPU_THREAD
# 58   Leave    1.311405e+08  MPI_Recv           1    CPU_THREAD
# 62   Enter    1.311438e+08  MPI_Recv           0    CPU_THREAD
# 65   Leave    1.312395e+08  MPI_Recv           0    CPU_THREAD
# 68   Enter    1.315609e+08  MPI_Recv           1    CPU_THREAD
# 70   Leave    1.316800e+08  MPI_Recv           1    CPU_THREAD
# 74   Enter    1.316834e+08  MPI_Recv           0    CPU_THREAD
# 77   Leave    1.318673e+08  MPI_Recv           0    CPU_THREAD
# 80   Enter    1.324879e+08  MPI_Recv           1    CPU_THREAD
# 82   Leave    1.327120e+08  MPI_Recv           1    CPU_THREAD
# 86   Enter    1.327154e+08  MPI_Recv           0    CPU_THREAD
# 89   Leave    1.330902e+08  MPI_Recv           0    CPU_THREAD
# 92   Enter    1.343140e+08  MPI_Recv           1    CPU_THREAD
# 94   Leave    1.347616e+08  MPI_Recv           1    CPU_THREAD
# 98   Enter    1.347653e+08  MPI_Recv           0    CPU_THREAD
# 101  Leave    1.354732e+08  MPI_Recv           0    CPU_THREAD
#
#     Location Group ID Location Group Type               Attributes
# 6                   1             PROCESS  {'region': 'Region 55'}
# 10                  0             PROCESS  {'region': 'Region 55'}
# 12                  1             PROCESS                     None
# 17                  0             PROCESS                     None
# 18                  1             PROCESS  {'region': 'Region 55'}
# 22                  0             PROCESS  {'region': 'Region 55'}
# 24                  1             PROCESS                     None
# 29                  0             PROCESS                     None
# 30                  1             PROCESS  {'region': 'Region 55'}
# 34                  1             PROCESS                     None
# 38                  0             PROCESS  {'region': 'Region 55'}
# 41                  0             PROCESS                     None
# 44                  1             PROCESS  {'region': 'Region 55'}
# 46                  1             PROCESS                     None
# 50                  0             PROCESS  {'region': 'Region 55'}
# 53                  0             PROCESS                     None
# 56                  1             PROCESS  {'region': 'Region 55'}
# 58                  1             PROCESS                     None
# 62                  0             PROCESS  {'region': 'Region 55'}
# 65                  0             PROCESS                     None
# 68                  1             PROCESS  {'region': 'Region 55'}
# 70                  1             PROCESS                     None
# 74                  0             PROCESS  {'region': 'Region 55'}
# 77                  0             PROCESS                     None
# 80                  1             PROCESS  {'region': 'Region 55'}
# 82                  1             PROCESS                     None
# 86                  0             PROCESS  {'region': 'Region 55'}
# 89                  0             PROCESS                     None
# 92                  1             PROCESS  {'region': 'Region 55'}
# 94                  1             PROCESS                     None
# 98                  0             PROCESS  {'region': 'Region 55'}
# 101                 0             PROCESS                     None

# %%
trace.where("Timestamp (ns)", "between", [1.307057e08, 1.356546e08]).get()
# Out:
#        Event  Timestamp (ns)          Name Location ID Location Type  \
# 37     Leave    1.307057e+08      MPI_Send           0    CPU_THREAD
# 38     Enter    1.307060e+08      MPI_Recv           0    CPU_THREAD
# 39   MpiRecv    1.307398e+08           N/A           0    CPU_THREAD
# 40     Leave    1.307398e+08      MPI_Send           1    CPU_THREAD
# 41     Leave    1.307403e+08      MPI_Recv           0    CPU_THREAD
# ..       ...             ...           ...         ...           ...
# 101    Leave    1.354732e+08      MPI_Recv           0    CPU_THREAD
# 102    Enter    1.354820e+08  MPI_Finalize           0    CPU_THREAD
# 103    Enter    1.356308e+08  MPI_Finalize           1    CPU_THREAD
# 104    Leave    1.356543e+08  MPI_Finalize           0    CPU_THREAD
# 105    Leave    1.356546e+08  MPI_Finalize           1    CPU_THREAD
#
#     Location Group ID Location Group Type  \
# 37                  0             PROCESS
# 38                  0             PROCESS
# 39                  0             PROCESS
# 40                  1             PROCESS
# 41                  0             PROCESS
# ..                ...                 ...
# 101                 0             PROCESS
# 102                 0             PROCESS
# 103                 1             PROCESS
# 104                 0             PROCESS
# 105                 1             PROCESS
#
#                                             Attributes
# 37                                                None
# 38                             {'region': 'Region 55'}
# 39   {'sender': 1, 'communicator': 'Comm 1', 'msg_t...
# 40                                                None
# 41                                                None
# ..                                                 ...
# 101                                               None
# 102                            {'region': 'Region 17'}
# 103                            {'region': 'Region 17'}
# 104                                               None
# 105                                               None
#
# [69 rows x 8 columns]

# %%
trace.where("Timestamp (ns)", "between", [1.307057e08, 1.356546e08]).where(
    "Location ID", "==", 1
).get()
# Out:
#        Event  Timestamp (ns)          Name Location ID Location Type  \
# 40     Leave    1.307398e+08      MPI_Send           1    CPU_THREAD
# 44     Enter    1.308216e+08      MPI_Recv           1    CPU_THREAD
# 45   MpiRecv    1.308553e+08           N/A           1    CPU_THREAD
# 46     Leave    1.308557e+08      MPI_Recv           1    CPU_THREAD
# 47     Enter    1.308561e+08      MPI_Send           1    CPU_THREAD
# 48   MpiSend    1.308563e+08           N/A           1    CPU_THREAD
# 52     Leave    1.309104e+08      MPI_Send           1    CPU_THREAD
# 56     Enter    1.310765e+08      MPI_Recv           1    CPU_THREAD
# 57   MpiRecv    1.311397e+08           N/A           1    CPU_THREAD
# 58     Leave    1.311405e+08      MPI_Recv           1    CPU_THREAD
# 59     Enter    1.311409e+08      MPI_Send           1    CPU_THREAD
# 60   MpiSend    1.311412e+08           N/A           1    CPU_THREAD
# 64     Leave    1.312394e+08      MPI_Send           1    CPU_THREAD
# 68     Enter    1.315609e+08      MPI_Recv           1    CPU_THREAD
# 69   MpiRecv    1.316793e+08           N/A           1    CPU_THREAD
# 70     Leave    1.316800e+08      MPI_Recv           1    CPU_THREAD
# 71     Enter    1.316805e+08      MPI_Send           1    CPU_THREAD
# 72   MpiSend    1.316807e+08           N/A           1    CPU_THREAD
# 76     Leave    1.318671e+08      MPI_Send           1    CPU_THREAD
# 80     Enter    1.324879e+08      MPI_Recv           1    CPU_THREAD
# 81   MpiRecv    1.327112e+08           N/A           1    CPU_THREAD
# 82     Leave    1.327120e+08      MPI_Recv           1    CPU_THREAD
# 83     Enter    1.327124e+08      MPI_Send           1    CPU_THREAD
# 84   MpiSend    1.327126e+08           N/A           1    CPU_THREAD
# 88     Leave    1.330901e+08      MPI_Send           1    CPU_THREAD
# 92     Enter    1.343140e+08      MPI_Recv           1    CPU_THREAD
# 93   MpiRecv    1.347609e+08           N/A           1    CPU_THREAD
# 94     Leave    1.347616e+08      MPI_Recv           1    CPU_THREAD
# 95     Enter    1.347620e+08      MPI_Send           1    CPU_THREAD
# 96   MpiSend    1.347623e+08           N/A           1    CPU_THREAD
# 99     Leave    1.354726e+08      MPI_Send           1    CPU_THREAD
# 103    Enter    1.356308e+08  MPI_Finalize           1    CPU_THREAD
# 105    Leave    1.356546e+08  MPI_Finalize           1    CPU_THREAD
#
#     Location Group ID Location Group Type  \
# 40                  1             PROCESS
# 44                  1             PROCESS
# 45                  1             PROCESS
# 46                  1             PROCESS
# 47                  1             PROCESS
# 48                  1             PROCESS
# 52                  1             PROCESS
# 56                  1             PROCESS
# 57                  1             PROCESS
# 58                  1             PROCESS
# 59                  1             PROCESS
# 60                  1             PROCESS
# 64                  1             PROCESS
# 68                  1             PROCESS
# 69                  1             PROCESS
# 70                  1             PROCESS
# 71                  1             PROCESS
# 72                  1             PROCESS
# 76                  1             PROCESS
# 80                  1             PROCESS
# 81                  1             PROCESS
# 82                  1             PROCESS
# 83                  1             PROCESS
# 84                  1             PROCESS
# 88                  1             PROCESS
# 92                  1             PROCESS
# 93                  1             PROCESS
# 94                  1             PROCESS
# 95                  1             PROCESS
# 96                  1             PROCESS
# 99                  1             PROCESS
# 103                 1             PROCESS
# 105                 1             PROCESS
#
#                                             Attributes
# 40                                                None
# 44                             {'region': 'Region 55'}
# 45   {'sender': 0, 'communicator': 'Comm 1', 'msg_t...
# 46                                                None
# 47                             {'region': 'Region 67'}
# 48   {'receiver': 0, 'communicator': 'Comm 1', 'msg...
# 52                                                None
# 56                             {'region': 'Region 55'}
# 57   {'sender': 0, 'communicator': 'Comm 1', 'msg_t...
# 58                                                None
# 59                             {'region': 'Region 67'}
# 60   {'receiver': 0, 'communicator': 'Comm 1', 'msg...
# 64                                                None
# 68                             {'region': 'Region 55'}
# 69   {'sender': 0, 'communicator': 'Comm 1', 'msg_t...
# 70                                                None
# 71                             {'region': 'Region 67'}
# 72   {'receiver': 0, 'communicator': 'Comm 1', 'msg...
# 76                                                None
# 80                             {'region': 'Region 55'}
# 81   {'sender': 0, 'communicator': 'Comm 1', 'msg_t...
# 82                                                None
# 83                             {'region': 'Region 67'}
# 84   {'receiver': 0, 'communicator': 'Comm 1', 'msg...
# 88                                                None
# 92                             {'region': 'Region 55'}
# 93   {'sender': 0, 'communicator': 'Comm 1', 'msg_t...
# 94                                                None
# 95                             {'region': 'Region 67'}
# 96   {'receiver': 0, 'communicator': 'Comm 1', 'msg...
# 99                                                None
# 103                            {'region': 'Region 17'}
# 105                                               None

# %%
q1 = (
    QueryBuilder()
    .where("Timestamp (ns)", ">", 0)
    .where("Timestamp (ns)", "<", 10)
    #     .orderBy("Process", "asc")
    #     .orderBy("Thread", "desc")
    #     .limit(100)
)
trace.get(q1)
# Out:
# Empty DataFrame
# Columns: [Event, Timestamp (ns), Name, Location ID, Location Type, Location Group ID, Location Group Type, Attributes]
# Index: []

# %%
trace.where("Event", "==", "ProgramBegin")

# %%
trace.where("Event", "==", "ProgramBegin").get()

# %%
from pipit.query import Where, And, Or, QueryBuilder

q1 = QueryBuilder(
    Where("Event", "==", "ProgramBegin") | Where("Event", "==", "ProgramEnd")
)
q1

# %%
trace.where("Name", "==", "MPI_Init").get()

# %%
q1 = trace.where("Location ID", "==", 1)
q2 = trace.where("Name", "==", "N/A")
q3 = trace.where("Name", "==", "MPI_Init")
(q1 & (q2 | q3)).get()

# %%
trace.where("Location ID", "in", [0, 1]).get()

# %%
(trace.where("Location ID", "==", 1) | trace.where("Name", "==", "N/A")).get()
