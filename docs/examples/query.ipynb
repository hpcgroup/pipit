# %%
# Set up notebook for development
# %load_ext autoreload
# %autoreload 2

# Set up paths
import sys

sys.path.append("../../.")
del sys.path[0]

import pipit as pp
import pandas as pd

# %%
df = pd.read_pickle("C:/Users/Rakrish/Downloads/pingPong.pkl", compression="zip")
trace = pp.Trace(None, df)
trace.events
# Out:
#             Event  Timestamp (ns)          Name Location ID Location Type  \
# 0    ProgramBegin    0.000000e+00           N/A           1    CPU_THREAD
# 1    ProgramBegin    1.295053e+05           N/A           0    CPU_THREAD
# 2           Enter    1.618990e+05      MPI_Init           0    CPU_THREAD
# 3           Enter    2.519928e+05      MPI_Init           1    CPU_THREAD
# 4           Leave    1.305041e+08      MPI_Init           1    CPU_THREAD
# ..            ...             ...           ...         ...           ...
# 103         Enter    1.356308e+08  MPI_Finalize           1    CPU_THREAD
# 104         Leave    1.356543e+08  MPI_Finalize           0    CPU_THREAD
# 105         Leave    1.356546e+08  MPI_Finalize           1    CPU_THREAD
# 106    ProgramEnd    1.356736e+08           N/A           1    CPU_THREAD
# 107    ProgramEnd    1.356740e+08           N/A           0    CPU_THREAD
#
#     Location Group ID Location Group Type  \
# 0                   1             PROCESS
# 1                   0             PROCESS
# 2                   0             PROCESS
# 3                   1             PROCESS
# 4                   1             PROCESS
# ..                ...                 ...
# 103                 1             PROCESS
# 104                 0             PROCESS
# 105                 1             PROCESS
# 106                 1             PROCESS
# 107                 0             PROCESS
#
#                                             Attributes
# 0    {'attributes': {'Attribute 2': 15968}, 'progra...
# 1    {'attributes': {'Attribute 2': 15964}, 'progra...
# 2                              {'region': 'Region 36'}
# 3                              {'region': 'Region 36'}
# 4                                                 None
# ..                                                 ...
# 103                            {'region': 'Region 17'}
# 104                                               None
# 105                                               None
# 106              {'exit_status': -9223372036854775808}
# 107              {'exit_status': -9223372036854775808}
#
# [108 rows x 8 columns]

# %%
from pipit.query import Where, And, Not, QueryBuilder

q1 = Where("Timestamp (ns)", "between", [5, 10])

(
    trace.where("Timestamp (ns)", "between", [0, 10e10])
    .where("Name", "==", "N/A")
    .where("Location ID", "==", 0)
    .limit(10)
    .orderBy("Timestamp (ns)", "desc")
    .limit(5)
).get()
# Out:
#       Event  Timestamp (ns) Name Location ID Location Type Location Group ID  \
# 55  MpiSend    1.309968e+08  N/A           0    CPU_THREAD                 0
# 51  MpiRecv    1.309102e+08  N/A           0    CPU_THREAD                 0
# 43  MpiSend    1.307812e+08  N/A           0    CPU_THREAD                 0
# 39  MpiRecv    1.307398e+08  N/A           0    CPU_THREAD                 0
# 32  MpiSend    1.306770e+08  N/A           0    CPU_THREAD                 0
#
#    Location Group Type                                         Attributes
# 55             PROCESS  {'receiver': 1, 'communicator': 'Comm 1', 'msg...
# 51             PROCESS  {'sender': 1, 'communicator': 'Comm 1', 'msg_t...
# 43             PROCESS  {'receiver': 1, 'communicator': 'Comm 1', 'msg...
# 39             PROCESS  {'sender': 1, 'communicator': 'Comm 1', 'msg_t...
# 32             PROCESS  {'receiver': 1, 'communicator': 'Comm 1', 'msg...

# %%
trace.where("Name", "==", "N/A").where("Location ID", "==", 1).where(
    "Event", "==", "MpiRecv"
).limit(5).get()
# Out:
#       Event  Timestamp (ns) Name Location ID Location Type Location Group ID  \
# 11  MpiRecv    1.305594e+08  N/A           1    CPU_THREAD                 1
# 23  MpiRecv    1.306359e+08  N/A           1    CPU_THREAD                 1
# 33  MpiRecv    1.307020e+08  N/A           1    CPU_THREAD                 1
# 45  MpiRecv    1.308553e+08  N/A           1    CPU_THREAD                 1
# 57  MpiRecv    1.311397e+08  N/A           1    CPU_THREAD                 1
#
#    Location Group Type                                         Attributes
# 11             PROCESS  {'sender': 0, 'communicator': 'Comm 1', 'msg_t...
# 23             PROCESS  {'sender': 0, 'communicator': 'Comm 1', 'msg_t...
# 33             PROCESS  {'sender': 0, 'communicator': 'Comm 1', 'msg_t...
# 45             PROCESS  {'sender': 0, 'communicator': 'Comm 1', 'msg_t...
# 57             PROCESS  {'sender': 0, 'communicator': 'Comm 1', 'msg_t...

# %%
trace.where("Name", "==", "N/A").get()

trace.where("Event", "in", ["MpiSend", "MpiRecv"]).get()
# Out:
#        Event  Timestamp (ns) Name Location ID Location Type Location Group ID  \
# 8    MpiSend    1.305406e+08  N/A           0    CPU_THREAD                 0
# 11   MpiRecv    1.305594e+08  N/A           1    CPU_THREAD                 1
# 14   MpiSend    1.305664e+08  N/A           1    CPU_THREAD                 1
# 16   MpiRecv    1.305818e+08  N/A           0    CPU_THREAD                 0
# 20   MpiSend    1.306161e+08  N/A           0    CPU_THREAD                 0
# 23   MpiRecv    1.306359e+08  N/A           1    CPU_THREAD                 1
# 26   MpiSend    1.306367e+08  N/A           1    CPU_THREAD                 1
# 28   MpiRecv    1.306552e+08  N/A           0    CPU_THREAD                 0
# 32   MpiSend    1.306770e+08  N/A           0    CPU_THREAD                 0
# 33   MpiRecv    1.307020e+08  N/A           1    CPU_THREAD                 1
# 36   MpiSend    1.307035e+08  N/A           1    CPU_THREAD                 1
# 39   MpiRecv    1.307398e+08  N/A           0    CPU_THREAD                 0
# 43   MpiSend    1.307812e+08  N/A           0    CPU_THREAD                 0
# 45   MpiRecv    1.308553e+08  N/A           1    CPU_THREAD                 1
# 48   MpiSend    1.308563e+08  N/A           1    CPU_THREAD                 1
# 51   MpiRecv    1.309102e+08  N/A           0    CPU_THREAD                 0
# 55   MpiSend    1.309968e+08  N/A           0    CPU_THREAD                 0
# 57   MpiRecv    1.311397e+08  N/A           1    CPU_THREAD                 1
# 60   MpiSend    1.311412e+08  N/A           1    CPU_THREAD                 1
# 63   MpiRecv    1.312391e+08  N/A           0    CPU_THREAD                 0
# 67   MpiSend    1.314049e+08  N/A           0    CPU_THREAD                 0
# 69   MpiRecv    1.316793e+08  N/A           1    CPU_THREAD                 1
# 72   MpiSend    1.316807e+08  N/A           1    CPU_THREAD                 1
# 75   MpiRecv    1.318669e+08  N/A           0    CPU_THREAD                 0
# 79   MpiSend    1.322016e+08  N/A           0    CPU_THREAD                 0
# 81   MpiRecv    1.327112e+08  N/A           1    CPU_THREAD                 1
# 84   MpiSend    1.327126e+08  N/A           1    CPU_THREAD                 1
# 87   MpiRecv    1.330897e+08  N/A           0    CPU_THREAD                 0
# 91   MpiSend    1.337305e+08  N/A           0    CPU_THREAD                 0
# 93   MpiRecv    1.347609e+08  N/A           1    CPU_THREAD                 1
# 96   MpiSend    1.347623e+08  N/A           1    CPU_THREAD                 1
# 100  MpiRecv    1.354727e+08  N/A           0    CPU_THREAD                 0
#
#     Location Group Type                                         Attributes
# 8               PROCESS  {'receiver': 1, 'communicator': 'Comm 1', 'msg...
# 11              PROCESS  {'sender': 0, 'communicator': 'Comm 1', 'msg_t...
# 14              PROCESS  {'receiver': 0, 'communicator': 'Comm 1', 'msg...
# 16              PROCESS  {'sender': 1, 'communicator': 'Comm 1', 'msg_t...
# 20              PROCESS  {'receiver': 1, 'communicator': 'Comm 1', 'msg...
# 23              PROCESS  {'sender': 0, 'communicator': 'Comm 1', 'msg_t...
# 26              PROCESS  {'receiver': 0, 'communicator': 'Comm 1', 'msg...
# 28              PROCESS  {'sender': 1, 'communicator': 'Comm 1', 'msg_t...
# 32              PROCESS  {'receiver': 1, 'communicator': 'Comm 1', 'msg...
# 33              PROCESS  {'sender': 0, 'communicator': 'Comm 1', 'msg_t...
# 36              PROCESS  {'receiver': 0, 'communicator': 'Comm 1', 'msg...
# 39              PROCESS  {'sender': 1, 'communicator': 'Comm 1', 'msg_t...
# 43              PROCESS  {'receiver': 1, 'communicator': 'Comm 1', 'msg...
# 45              PROCESS  {'sender': 0, 'communicator': 'Comm 1', 'msg_t...
# 48              PROCESS  {'receiver': 0, 'communicator': 'Comm 1', 'msg...
# 51              PROCESS  {'sender': 1, 'communicator': 'Comm 1', 'msg_t...
# 55              PROCESS  {'receiver': 1, 'communicator': 'Comm 1', 'msg...
# 57              PROCESS  {'sender': 0, 'communicator': 'Comm 1', 'msg_t...
# 60              PROCESS  {'receiver': 0, 'communicator': 'Comm 1', 'msg...
# 63              PROCESS  {'sender': 1, 'communicator': 'Comm 1', 'msg_t...
# 67              PROCESS  {'receiver': 1, 'communicator': 'Comm 1', 'msg...
# 69              PROCESS  {'sender': 0, 'communicator': 'Comm 1', 'msg_t...
# 72              PROCESS  {'receiver': 0, 'communicator': 'Comm 1', 'msg...
# 75              PROCESS  {'sender': 1, 'communicator': 'Comm 1', 'msg_t...
# 79              PROCESS  {'receiver': 1, 'communicator': 'Comm 1', 'msg...
# 81              PROCESS  {'sender': 0, 'communicator': 'Comm 1', 'msg_t...
# 84              PROCESS  {'receiver': 0, 'communicator': 'Comm 1', 'msg...
# 87              PROCESS  {'sender': 1, 'communicator': 'Comm 1', 'msg_t...
# 91              PROCESS  {'receiver': 1, 'communicator': 'Comm 1', 'msg...
# 93              PROCESS  {'sender': 0, 'communicator': 'Comm 1', 'msg_t...
# 96              PROCESS  {'receiver': 0, 'communicator': 'Comm 1', 'msg...
# 100             PROCESS  {'sender': 1, 'communicator': 'Comm 1', 'msg_t...

# %%
q1 = (
    trace.where("Timestamp (ns)", "<", 1.35e08)
    .where("Name", "==", "MPI_Init")
    .limit(200)
)
q1

# %%
# Simple filter
q1 = trace.where("Timestamp (ns)", "<", 1.35e08).where("Name", "==", "MPI_Init")
q1


q1 = trace.where("Timestamp (ns)", "between", [2.5e05, 1.35e08]).where(
    "Name", "==", "MPI_Init"
)
# trace.events.query(q1)
q1

q1 = trace.where("Timestamp (ns)", "between", [0, 1.305041e08]).where(
    "Event", "==", "Enter"
)
q1.orderBy("Location ID", "desc").orderBy("Name", "asc").get()

# %%
q1 = trace.where("Timestamp (ns)", "between", [0, 1.305041e08]).limit(10)
q2 = trace.where("Event", "==", "Enter").limit(10)
(q1 & q2).limit(100).orderBy("Name")
# Out:
# Query [Where (`Timestamp (ns)` >= 0) & (`Timestamp (ns)` <= 130504100.0), Where `Event` == 'Enter', Limit 100 (head), OrderBy 'Name' (asc)]

# %%
# Execute simple filter
trace.where("Timestamp (ns)", "<", 1.35e08).orderBy("Timestamp (ns)", "desc").get()

# %%
q1 = trace.where("Location ID", "==", 1)
q2 = trace.where("Name", "==", "N/A")
q3 = trace.where("Name", "==", "MPI_Init")
q4 = trace.where("Timestamp (ns)", "between", [1.35e08, 2.5e05])

# (q1 & (q2 | q3)).get()

# %%
# Logical AND
trace.where("Timestamp (ns)", "<=", 1.35e08).where("Timestamp (ns)", ">=", 2.5e05).get()

# %%
# Logical OR
trace.where("Name", "in", ["MPI_Recv", "MpiSend", "ProgramEnd"]).get()

# %%
trace.where("Timestamp (ns)", "between", [1.307057e08, 1.356546e08]).get()

# %%
trace.where("Timestamp (ns)", "between", [1.307057e08, 1.356546e08]).where(
    "Location ID", "==", 1
).get()

# %%
q1 = (
    QueryBuilder()
    .where("Timestamp (ns)", ">", 0)
    .where("Timestamp (ns)", "<", 10)
    #     .orderBy("Process", "asc")
    #     .orderBy("Thread", "desc")
    #     .limit(100)
)
trace.get(q1)

# %%
trace.where("Event", "==", "ProgramBegin")

# %%
trace.where("Event", "==", "ProgramBegin").get()

# %%
from pipit.query import Where, And, Or, QueryBuilder

q1 = QueryBuilder(
    Where("Event", "==", "ProgramBegin") | Where("Event", "==", "ProgramEnd")
)
q1

# %%
trace.where("Name", "==", "MPI_Init").get()

# %%
q1 = trace.where("Location ID", "==", 1)
q2 = trace.where("Name", "==", "N/A")
q3 = trace.where("Name", "==", "MPI_Init")
(q1 & (q2 | q3)).get()

q1 = Where("Location ID", "==", 1)
q2 = Where("Name", "==", "N/A")
q3 = Where("Name", "==", "MPI_Init")
trace.query(q1 & (q2 | q3)).get()

# %%
trace.where("Location ID", "in", [0, 1]).get()

# %%
(trace.where("Location ID", "==", 1) | trace.where("Name", "==", "N/A")).get()

# %%
# Use pandas query
trace.where("(`Location ID` == 1) & (`Timestamp (ns)` > 1.24)").get()

# %%
q1 = Where("timestamp", "between", [0, 100])
trace.query(q1).get()

# %%
trace.where("Name", "==", "N/A").orderBy("Location ID", "desc").orderBy("Event").get()
