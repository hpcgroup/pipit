# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("../../")    # modify the path based on your notebook location

# %%
import pipit as pp
import polars as pl

# %%
trace = pp.Trace.from_parquet("./amg_16.parquet")

# %%
trace.events
# Out:
# <LazyFrame [6 cols, {"Timestamp (ns)": Float64 … "Attributes": Binary}] at 0x7FE2C49E2DF0>

# %%
def preview(polars_df):
    print(len(polars_df))

# %%
trace.events.select(pl.count()).collect()
# Out:
# shape: (1, 1)
# ┌─────────┐
# │ count   │
# │ ---     │
# │ u32     │
# ╞═════════╡
# │ 5010751 │
# └─────────┘

# %%
pl.scan_parquet("./amg_16.parquet").head().collect()
# Out:
# shape: (5, 6)
# ┌────────────────┬────────────┬──────────────┬────────┬─────────┬───────────────┐
# │ Timestamp (ns) ┆ Event Type ┆ Name         ┆ Thread ┆ Process ┆ Attributes    │
# │ ---            ┆ ---        ┆ ---          ┆ ---    ┆ ---     ┆ ---           │
# │ f64            ┆ str        ┆ str          ┆ i64    ┆ i64     ┆ binary        │
# ╞════════════════╪════════════╪══════════════╪════════╪═════════╪═══════════════╡
# │ 0.0            ┆ Instant    ┆ ProgramBegin ┆ 0      ┆ 12      ┆ [binary data] │
# │ 46.774703      ┆ Instant    ┆ ProgramBegin ┆ 0      ┆ 13      ┆ [binary data] │
# │ 71.593933      ┆ Instant    ┆ ProgramBegin ┆ 0      ┆ 15      ┆ [binary data] │
# │ 100.231506     ┆ Instant    ┆ ProgramBegin ┆ 0      ┆ 14      ┆ [binary data] │
# │ 24849.776813   ┆ Enter      ┆ MPI_Init     ┆ 0      ┆ 15      ┆ [binary data] │
# └────────────────┴────────────┴──────────────┴────────┴─────────┴───────────────┘

# %%
pl.scan_parquet("./amg_16.parquet").tail().collect()
# Out:
# shape: (5, 6)
# ┌────────────────┬────────────┬─────────────────────┬────────┬─────────┬───────────────┐
# │ Timestamp (ns) ┆ Event Type ┆ Name                ┆ Thread ┆ Process ┆ Attributes    │
# │ ---            ┆ ---        ┆ ---                 ┆ ---    ┆ ---     ┆ ---           │
# │ f64            ┆ str        ┆ str                 ┆ i64    ┆ i64     ┆ binary        │
# ╞════════════════╪════════════╪═════════════════════╪════════╪═════════╪═══════════════╡
# │ 3.3157e9       ┆ Instant    ┆ MeasurementOnOff    ┆ 0      ┆ 5       ┆ [binary data] │
# │ 3.3157e9       ┆ Instant    ┆ MeasurementOnOff    ┆ 0      ┆ 6       ┆ [binary data] │
# │ 3.3157e9       ┆ Instant    ┆ MeasurementOnOff    ┆ 0      ┆ 7       ┆ [binary data] │
# │ 3.3157e9       ┆ Leave      ┆ TRACER_WallTime_amg ┆ 0      ┆ 0       ┆ null          │
# │ 3.3157e9       ┆ Instant    ┆ MeasurementOnOff    ┆ 0      ┆ 0       ┆ [binary data] │
# └────────────────┴────────────┴─────────────────────┴────────┴─────────┴───────────────┘

# %%
q.collect(streaming=True)
# Out:
# shape: (5_010_735, 1)
# ┌─────────┐
# │ Process │
# │ ---     │
# │ i64     │
# ╞═════════╡
# │ 6       │
# │ 7       │
# │ 5       │
# │ 4       │
# │ …       │
# │ 6       │
# │ 7       │
# │ 0       │
# │ 0       │
# └─────────┘

# %%
trace = pp.Trace.from_otf2("../../pipit/tests/data/ping-pong-otf2/")

# %%
pandas_df = trace.events
pandas_df
# Out:
#      Timestamp (ns) Event Type                   Name Thread Process  \
# 0      0.000000e+00    Instant           ProgramBegin      0       1
# 1      3.008309e+04      Enter  int main(int, char**)      0       1
# 2      4.028833e+04      Enter               MPI_Init      0       1
# 3      3.077309e+05    Instant           ProgramBegin      0       0
# 4      3.369797e+05      Enter  int main(int, char**)      0       0
# ..              ...        ...                    ...    ...     ...
# 115    1.995748e+08      Leave           MPI_Finalize      0       1
# 116    1.995752e+08      Leave  int main(int, char**)      0       0
# 117    1.995768e+08      Leave  int main(int, char**)      0       1
# 118    1.996033e+08    Instant             ProgramEnd      0       0
# 119    1.996045e+08    Instant             ProgramEnd      0       1
#
#                                             Attributes
# 0    {'attributes': {'Attribute 2': 26602}, 'progra...
# 1                               {'region': 'Region 3'}
# 2                             {'region': 'Region 148'}
# 3    {'attributes': {'Attribute 2': 26601}, 'progra...
# 4                               {'region': 'Region 3'}
# ..                                                 ...
# 115                                               None
# 116                                               None
# 117                                               None
# 118              {'exit_status': -9223372036854775808}
# 119              {'exit_status': -9223372036854775808}
#
# [120 rows x 6 columns]

# %%
pandas_df["Process"] = pandas_df["Process"].astype("int")
pandas_df["Thread"] = pandas_df["Thread"].astype("int")
pandas_df.dtypes
# Out:
# Timestamp (ns)     float64
# Event Type        category
# Name              category
# Thread               int64
# Process              int64
# Attributes          object
# dtype: object

# %%
polars_df = pl.from_pandas(pandas_df)

# %%
polars_df
# Out:
# shape: (120, 6)
# ┌────────────────┬────────────┬───────────────────────┬────────┬─────────┬─────────────────────────┐
# │ Timestamp (ns) ┆ Event Type ┆ Name                  ┆ Thread ┆ Process ┆ Attributes              │
# │ ---            ┆ ---        ┆ ---                   ┆ ---    ┆ ---     ┆ ---                     │
# │ f64            ┆ cat        ┆ cat                   ┆ i64    ┆ i64     ┆ struct[10]              │
# ╞════════════════╪════════════╪═══════════════════════╪════════╪═════════╪═════════════════════════╡
# │ 0.0            ┆ Instant    ┆ ProgramBegin          ┆ 0      ┆ 1       ┆ {{26602},null,null,null │
# │                ┆            ┆                       ┆        ┆         ┆ ,null,[],…              │
# │ 30083.086937   ┆ Enter      ┆ int main(int, char**) ┆ 0      ┆ 1       ┆ {{null},null,null,null, │
# │                ┆            ┆                       ┆        ┆         ┆ null,null…              │
# │ 40288.331502   ┆ Enter      ┆ MPI_Init              ┆ 0      ┆ 1       ┆ {{null},null,null,null, │
# │                ┆            ┆                       ┆        ┆         ┆ null,null…              │
# │ 307730.935817  ┆ Instant    ┆ ProgramBegin          ┆ 0      ┆ 0       ┆ {{26601},null,null,null │
# │                ┆            ┆                       ┆        ┆         ┆ ,null,[],…              │
# │ …              ┆ …          ┆ …                     ┆ …      ┆ …       ┆ …                       │
# │ 1.9958e8       ┆ Leave      ┆ int main(int, char**) ┆ 0      ┆ 0       ┆ {{null},null,null,null, │
# │                ┆            ┆                       ┆        ┆         ┆ null,null…              │
# │ 1.9958e8       ┆ Leave      ┆ int main(int, char**) ┆ 0      ┆ 1       ┆ {{null},null,null,null, │
# │                ┆            ┆                       ┆        ┆         ┆ null,null…              │
# │ 1.9960e8       ┆ Instant    ┆ ProgramEnd            ┆ 0      ┆ 0       ┆ {{null},null,-922337203 │
# │                ┆            ┆                       ┆        ┆         ┆ 685477580…              │
# │ 1.9960e8       ┆ Instant    ┆ ProgramEnd            ┆ 0      ┆ 1       ┆ {{null},null,-922337203 │
# │                ┆            ┆                       ┆        ┆         ┆ 685477580…              │
# └────────────────┴────────────┴───────────────────────┴────────┴─────────┴─────────────────────────┘

# %%
polars_df_2 = pl.scan_parquet("/home/rakrish/amg_16.parquet/Process=0/part.0.parquet")
polars_df_2.sink_parquet("./trace.parquet")

# %%
polars_df_2
# Out:
# <LazyFrame [7 cols, {"Timestamp (ns)": Float64 … "Process": Int64}] at 0x7F1757769E80>

# %%
import pipit as pp
trace = pp.Trace.from_otf2("../../pipit/tests/data/ping-pong-otf2/")

# %%
trace.plot_timeline()
# Out:
#                 <style>
#                 @import url('https://fonts.cdnfonts.com/css/gill-sans?styles=17575');
#                 </style>
# <script id="1671">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:36891/autoload.js?bokeh-autoload-element=1671&bokeh-absolute-url=http://localhost:36891&resources=none", true);
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>

# %%
pandas_df = trace.events

# %%
pandas_df["Process"] = pandas_df["Process"].astype(int)
pandas_df["Thread"] = pandas_df["Thread"].astype(int)

# %%
polars_df = pl.from_pandas(pandas_df)

# %%
polars_df
# Out:
# shape: (5_010_751, 6)
# ┌────────────────┬────────────┬─────────────────────┬────────┬─────────┬───────────────────────────┐
# │ Timestamp (ns) ┆ Event Type ┆ Name                ┆ Thread ┆ Process ┆ Attributes                │
# │ ---            ┆ ---        ┆ ---                 ┆ ---    ┆ ---     ┆ ---                       │
# │ f64            ┆ cat        ┆ cat                 ┆ i64    ┆ i64     ┆ struct[14]                │
# ╞════════════════╪════════════╪═════════════════════╪════════╪═════════╪═══════════════════════════╡
# │ 0.0            ┆ Instant    ┆ ProgramBegin        ┆ 0      ┆ 12      ┆ {null,null,null,null,null │
# │                ┆            ┆                     ┆        ┆         ┆ ,["-pro…                  │
# │ 46.774703      ┆ Instant    ┆ ProgramBegin        ┆ 0      ┆ 13      ┆ {null,null,null,null,null │
# │                ┆            ┆                     ┆        ┆         ┆ ,["-pro…                  │
# │ 71.593933      ┆ Instant    ┆ ProgramBegin        ┆ 0      ┆ 15      ┆ {null,null,null,null,null │
# │                ┆            ┆                     ┆        ┆         ┆ ,["-pro…                  │
# │ 100.231506     ┆ Instant    ┆ ProgramBegin        ┆ 0      ┆ 14      ┆ {null,null,null,null,null │
# │                ┆            ┆                     ┆        ┆         ┆ ,["-pro…                  │
# │ …              ┆ …          ┆ …                   ┆ …      ┆ …       ┆ …                         │
# │ 3.3157e9       ┆ Instant    ┆ MeasurementOnOff    ┆ 0      ┆ 6       ┆ {null,null,"MeasurementMo │
# │                ┆            ┆                     ┆        ┆         ┆ de.OFF"…                  │
# │ 3.3157e9       ┆ Instant    ┆ MeasurementOnOff    ┆ 0      ┆ 7       ┆ {null,null,"MeasurementMo │
# │                ┆            ┆                     ┆        ┆         ┆ de.OFF"…                  │
# │ 3.3157e9       ┆ Leave      ┆ TRACER_WallTime_amg ┆ 0      ┆ 0       ┆ {null,null,null,null,null │
# │                ┆            ┆                     ┆        ┆         ┆ ,null,n…                  │
# │ 3.3157e9       ┆ Instant    ┆ MeasurementOnOff    ┆ 0      ┆ 0       ┆ {null,null,"MeasurementMo │
# │                ┆            ┆                     ┆        ┆         ┆ de.OFF"…                  │
# └────────────────┴────────────┴─────────────────────┴────────┴─────────┴───────────────────────────┘

# %%
polars_df['Attributes'].dtype
# Out:
# Struct([Field('collective_op', Utf8), Field('communicator', Utf8), Field('measurement_mode', Utf8), Field('msg_length', Int64), Field('msg_tag', Int64), Field('program_arguments', List(Utf8)), Field('program_name', Utf8), Field('receiver', Int64), Field('region', Utf8), Field('request_id', Int64), Field('root', Int64), Field('sender', Int64), Field('size_received', Int64), Field('size_sent', Int64)])

# %%
polars_df['Attributes'].dtype
# Out:
# Struct([Field('collective_op', Utf8), Field('communicator', Utf8), Field('measurement_mode', Utf8), Field('msg_length', Int64), Field('msg_tag', Int64), Field('program_arguments', List(Utf8)), Field('program_name', Utf8), Field('receiver', Int64), Field('region', Utf8), Field('request_id', Int64), Field('root', Int64), Field('sender', Int64), Field('size_received', Int64), Field('size_sent', Int64)])

# %%
import polars as pl

# %%
df = pl.read_parquet("./amg_16.parquet")

# %%
df
# Out:
# shape: (5_010_751, 6)
# ┌────────────────┬────────────┬─────────────────────┬────────┬─────────┬───────────────┐
# │ Timestamp (ns) ┆ Event Type ┆ Name                ┆ Thread ┆ Process ┆ Attributes    │
# │ ---            ┆ ---        ┆ ---                 ┆ ---    ┆ ---     ┆ ---           │
# │ f64            ┆ str        ┆ str                 ┆ i64    ┆ i64     ┆ binary        │
# ╞════════════════╪════════════╪═════════════════════╪════════╪═════════╪═══════════════╡
# │ 0.0            ┆ Instant    ┆ ProgramBegin        ┆ 0      ┆ 12      ┆ [binary data] │
# │ 46.774703      ┆ Instant    ┆ ProgramBegin        ┆ 0      ┆ 13      ┆ [binary data] │
# │ 71.593933      ┆ Instant    ┆ ProgramBegin        ┆ 0      ┆ 15      ┆ [binary data] │
# │ 100.231506     ┆ Instant    ┆ ProgramBegin        ┆ 0      ┆ 14      ┆ [binary data] │
# │ …              ┆ …          ┆ …                   ┆ …      ┆ …       ┆ …             │
# │ 3.3157e9       ┆ Instant    ┆ MeasurementOnOff    ┆ 0      ┆ 6       ┆ [binary data] │
# │ 3.3157e9       ┆ Instant    ┆ MeasurementOnOff    ┆ 0      ┆ 7       ┆ [binary data] │
# │ 3.3157e9       ┆ Leave      ┆ TRACER_WallTime_amg ┆ 0      ┆ 0       ┆ null          │
# │ 3.3157e9       ┆ Instant    ┆ MeasurementOnOff    ┆ 0      ┆ 0       ┆ [binary data] │
# └────────────────┴────────────┴─────────────────────┴────────┴─────────┴───────────────┘

# %%
df[0]['Attributes'].cast(dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [63], line 1
# ----> 1 df[0]['Attributes'].cast(dict)
#
# File ~/.local/lib/python3.8/site-packages/polars/series/series.py:3795, in Series.cast(self, dtype, strict)
#    3761 """
#    3762 Cast between data types.
#    3763
#    (...)
#    3792
#    3793 """
#    3794 # Do not dispatch cast as it is expensive and used in other functions.
# -> 3795 dtype = py_type_to_dtype(dtype)
#    3796 return self._from_pyseries(self._s.cast(dtype, strict))
#
# File ~/.local/lib/python3.8/site-packages/polars/datatypes/convert.py:433, in py_type_to_dtype(data_type, raise_unmatched, allow_strings)
#     431 if not raise_unmatched:
#     432     return None
# --> 433 raise ValueError(
#     434     f"cannot infer dtype from {data_type!r} (type: {type(data_type).__name__!r})"
#     435 ) from None
#
# ValueError: cannot infer dtype from <class 'dict'> (type: 'type')

# %%
df['Timestamp (ns)'].mean()
# Out:
# 1920105043.6460829

# %%
df["Event Type"].unique()
# Out:
# shape: (3,)
# Series: 'Event Type' [str]
# [
# 	"Instant"
# 	"Leave"
# 	"Enter"
# ]

# %%
df.group_by("Process").agg(pl.col("Timestamp (ns)").max())
# Out:
# shape: (16, 2)
# ┌─────────┬────────────────┐
# │ Process ┆ Timestamp (ns) │
# │ ---     ┆ ---            │
# │ i64     ┆ f64            │
# ╞═════════╪════════════════╡
# │ 0       ┆ 3.3157e9       │
# │ 5       ┆ 3.3157e9       │
# │ 10      ┆ 3.3157e9       │
# │ 14      ┆ 3.3157e9       │
# │ …       ┆ …              │
# │ 6       ┆ 3.3157e9       │
# │ 11      ┆ 3.3157e9       │
# │ 1       ┆ 3.3157e9       │
# │ 13      ┆ 3.3157e9       │
# └─────────┴────────────────┘

# %%
df.filter((pl.col("Timestamp (ns)") > 3e5) & (pl.col("Timestamp (ns)") < 1e8))
# Out:
# shape: (16, 6)
# ┌────────────────┬────────────┬──────────────┬────────┬─────────┬───────────────┐
# │ Timestamp (ns) ┆ Event Type ┆ Name         ┆ Thread ┆ Process ┆ Attributes    │
# │ ---            ┆ ---        ┆ ---          ┆ ---    ┆ ---     ┆ ---           │
# │ f64            ┆ str        ┆ str          ┆ i64    ┆ i64     ┆ binary        │
# ╞════════════════╪════════════╪══════════════╪════════╪═════════╪═══════════════╡
# │ 4.7639e7       ┆ Instant    ┆ ProgramBegin ┆ 0      ┆ 6       ┆ [binary data] │
# │ 4.7640e7       ┆ Instant    ┆ ProgramBegin ┆ 0      ┆ 7       ┆ [binary data] │
# │ 4.7643e7       ┆ Instant    ┆ ProgramBegin ┆ 0      ┆ 5       ┆ [binary data] │
# │ 4.7646e7       ┆ Instant    ┆ ProgramBegin ┆ 0      ┆ 4       ┆ [binary data] │
# │ …              ┆ …          ┆ …            ┆ …      ┆ …       ┆ …             │
# │ 4.7693e7       ┆ Enter      ┆ MPI_Init     ┆ 0      ┆ 1       ┆ [binary data] │
# │ 4.7693e7       ┆ Enter      ┆ MPI_Init     ┆ 0      ┆ 3       ┆ [binary data] │
# │ 4.7700e7       ┆ Enter      ┆ MPI_Init     ┆ 0      ┆ 2       ┆ [binary data] │
# │ 4.7719e7       ┆ Enter      ┆ MPI_Init     ┆ 0      ┆ 0       ┆ [binary data] │
# └────────────────┴────────────┴──────────────┴────────┴─────────┴───────────────┘

# %%
df[0]['Attributes']
# Out:
# shape: (1,)
# Series: 'Attributes' [binary]
# [
# 	[binary data]
# ]

# %%
len(df.filter(pl.col("Name") == "MPI_Init"))
# Out:
# 32

# %%
class Trace:
    def __init__(self, df):
        self.df = df
        
    def query(self, query):
        return pl.SQLContext(events=df).execute(query).collect()

# %%
trace = Trace(df)

# %%
trace.query(
"""
SELECT e1.Name FROM events e1, events e2
WHERE Process=4
""")
# Out:
# shape: (260_379, 1)
# ┌──────────────────┐
# │ Name             │
# │ ---              │
# │ str              │
# ╞══════════════════╡
# │ ProgramBegin     │
# │ MPI_Init         │
# │ MPI_Init         │
# │ MeasurementOnOff │
# │ …                │
# │ MPI_Allreduce    │
# │ MpiCollectiveEnd │
# │ MPI_Allreduce    │
# │ MeasurementOnOff │
# └──────────────────┘

# %%
trace.where("Process", "==", 0).plot_timeline()
